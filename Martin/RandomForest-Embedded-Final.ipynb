# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.pipeline import make_pipeline
import pandas as pd
from sklearn.feature_selection import SelectFromModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse.construct import random
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
from sklearn.model_selection import StratifiedKFold
from random import *    
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score

df = pd.read_csv("kasMasterNew.csv",sep=';')
#print("data shape: ", df.shape)
#print("data head: ", df.head)

first_column = df.columns[0]
df = df.drop([first_column], axis=1)
feature_labels = df.columns
last = df.iloc[:,-1]
df = df.iloc[:, :-1]

X = df
y = np.ravel(last)
model = list()
features = list()
X = X.to_numpy()

# %%
model = list()
features = list()

for x in range(1,2):
    folds = 6
    skf = StratifiedKFold(n_splits=folds, random_state=randint(1, 20000), shuffle=True, )
    skf.get_n_splits(X, y)
    acc_score = []
    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        scale = StandardScaler()
        scaler = scale.fit(X_train)

        X_train_transformed = scaler.transform(X_train)
        X_test_transformed = scaler.transform(X_test)

        #selector = SelectFromModel(RandomForestClassifier(n_estimators=400, n_jobs=-1, min_samples_split=2, min_samples_leaf=2, max_features='sqrt', max_depth = 40 ), max_features=47, threshold=-np.inf)
        selector = SelectFromModel(RandomForestClassifier(), max_features=50, threshold=-np.inf)
        selector.fit(X_train_transformed, y_train)

        X_train_rfc = selector.transform(X_train_transformed)
        X_test_rfc = selector.transform(X_test_transformed)
        
        #clf = RandomForestClassifier(n_estimators=400, n_jobs=-1, min_samples_split=2, min_samples_leaf=2, max_features='sqrt', max_depth = 40)
        clf = RandomForestClassifier()
        clf.fit(X_train_rfc, y_train)
        
        y_pred = clf.predict(X_test_rfc)
        
        #print('Accuracy on test set: ')
        print(accuracy_score(y_test, y_pred))
        print(confusion_matrix(y_test,y_pred))
        print(classification_report(y_test,y_pred))
        acc_score.append(accuracy_score(y_test, y_pred))
        
        
        features.append(df.columns[selector.get_support()])
    model.append(acc_score)
    print("Average score:", np.mean(acc_score))
    #model.append(acc_score)             
print("Model:", model)
# Out:
# 0.900523560209424
# [[28  1  0  0  1]
#  [ 0 12  0  1  0]
#  [ 0  0 84  4  1]
#  [ 0  0  8 26  0]
#  [ 1  1  1  0 22]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.93      0.95        30
#         Her2       0.86      0.92      0.89        13
#         LumA       0.90      0.94      0.92        89
#         LumB       0.84      0.76      0.80        34
#       Normal       0.92      0.88      0.90        25
#
#     accuracy                           0.90       191
#    macro avg       0.90      0.89      0.89       191
# weighted avg       0.90      0.90      0.90       191
#
# 0.9267015706806283
# [[30  0  0  0  0]
#  [ 0 12  0  1  0]
#  [ 0  0 87  1  1]
#  [ 0  1  7 26  0]
#  [ 0  0  3  0 22]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        30
#         Her2       0.92      0.92      0.92        13
#         LumA       0.90      0.98      0.94        89
#         LumB       0.93      0.76      0.84        34
#       Normal       0.96      0.88      0.92        25
#
#     accuracy                           0.93       191
#    macro avg       0.94      0.91      0.92       191
# weighted avg       0.93      0.93      0.93       191
#
# 0.9162303664921466
# [[31  0  0  0  0]
#  [ 0  9  0  4  0]
#  [ 0  0 81  7  1]
#  [ 0  0  3 30  0]
#  [ 0  0  1  0 24]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        31
#         Her2       1.00      0.69      0.82        13
#         LumA       0.95      0.91      0.93        89
#         LumB       0.73      0.91      0.81        33
#       Normal       0.96      0.96      0.96        25
#
#     accuracy                           0.92       191
#    macro avg       0.93      0.89      0.90       191
# weighted avg       0.93      0.92      0.92       191
#
# 0.837696335078534
# [[29  1  0  0  1]
#  [ 0 10  1  2  0]
#  [ 0  0 79  6  3]
#  [ 0  0 13 21  0]
#  [ 1  1  1  1 21]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.94      0.95        31
#         Her2       0.83      0.77      0.80        13
#         LumA       0.84      0.90      0.87        88
#         LumB       0.70      0.62      0.66        34
#       Normal       0.84      0.84      0.84        25
#
#     accuracy                           0.84       191
#    macro avg       0.84      0.81      0.82       191
# weighted avg       0.84      0.84      0.84       191
#
# 0.8842105263157894
# [[29  0  0  1  0]
#  [ 0 11  0  2  0]
#  [ 0  0 83  6  0]
#  [ 0  0  6 28  0]
#  [ 2  1  4  0 17]]
#               precision    recall  f1-score   support
#
#        Basal       0.94      0.97      0.95        30
#         Her2       0.92      0.85      0.88        13
#         LumA       0.89      0.93      0.91        89
#         LumB       0.76      0.82      0.79        34
#       Normal       1.00      0.71      0.83        24
#
#     accuracy                           0.88       190
#    macro avg       0.90      0.86      0.87       190
# weighted avg       0.89      0.88      0.88       190
#
# 0.8526315789473684
# [[29  1  0  0  0]
#  [ 1  8  2  2  0]
#  [ 0  0 81  8  0]
#  [ 0  0 11 23  0]
#  [ 0  0  3  0 21]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        30
#         Her2       0.89      0.62      0.73        13
#         LumA       0.84      0.91      0.87        89
#         LumB       0.70      0.68      0.69        34
#       Normal       1.00      0.88      0.93        24
#
#     accuracy                           0.85       190
#    macro avg       0.88      0.81      0.84       190
# weighted avg       0.86      0.85      0.85       190
#
# Average score: 0.8863323229539818
# Model: [[0.900523560209424, 0.9267015706806283, 0.9162303664921466, 0.837696335078534, 0.8842105263157894, 0.8526315789473684]]

# %%
pam50 = ['ACTR3B','ANLN','BAG1','BCL2','BIRC5','BLVRA','CCNB1','CCNE1','CDC20','CDC6',
'CDH3','CENPF','CEP55','CXXC5','EGFR','ERBB2','EXO1','FGFR4','FOXA1',
'FOXC1','GPR160','GRB7','KIF2C','KRT14','KRT17','KRT5','MAPT','MDM2','MELK',
'MIA','MKI67','MLPH','MMP11','MYBL2','MYC','NAT1','ORC6L','PGR','PHGDH','PTTG1','RRM2',
'SFRP1','SLC39A6','TMEM45B','TYMS','UBE2C','UBE2T']

# not in out data set : ['SR1', 'KNTC2', 'CDCA1'] so deleted from pam 50.



best50 = df[features[1]] # of latest best features
p = df[pam50]

from numpy.random import seed
from scipy.stats import pearsonr

# seed random number generator
seed(1)
# prepare data
#best50 = best50.iloc[:, 0:2]
#p = p.iloc[:, 0:2]
ll = list()
# calculate Pearson's correlation
col = list()
for ind, colum in enumerate(best50.columns):
    #corr, _ = pearsonr(p.columns[ind], column)
    #l.appende(corr)
    for ins, column in enumerate(p.columns):
        #print(colum)
        #print(column)
        #print(p.columns[ind])
        #print(ind)
        #print(best50.columns[ins])
        #print(ins)
        corr, _ = pearsonr(p[column], best50[colum])
        #print(abs(corr))
        col.append(abs(corr))
    ll.append(col)
    col=[] 
#print(l)  

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

fig, ax = plt.subplots(figsize=(46, 46))
#plt.xlabel(best50.columns)
#plt.ylabel(p.columns)

#fig.title('Pearson Absolute Values', fontsize=40)

x_axis_labels = best50.columns.to_numpy() # labels for x-axis
y_axis_labels =  p.columns.to_numpy()# labels for y-axis

# create seabvorn heatmap with required labels
b = sb.heatmap(np.array(ll).T.tolist(),  xticklabels=x_axis_labels, yticklabels=y_axis_labels,
           linewidth=0.4, cbar_kws={"shrink": .8}, fmt=".2f",square=True)
b.axes.set_title("Random Forest - Embedded feature selection - Pam50 vs Best50\n ",fontsize=60)
b.set_xlabel("Best 50",fontsize=40)
b.set_ylabel("Pam50",fontsize=40)
b.tick_params(labelsize=30)
sb.set(font_scale=3)
plt.show()
plt.savefig('HeatMap-Pam50vsFeatureSelectionBest50-166 RandomForest.jpg',dpi=400)

# %%
model = list()
X_t=df[features[1]].to_numpy()
for x in range(1,11):
    folds = 5
    skf = StratifiedKFold(n_splits=folds, random_state=randint(1, 1000), shuffle=True, )
    skf.get_n_splits(X_t, y)
    acc_score = []
    for train_index, test_index in skf.split(X_t, y):
        X_train, X_test = X_t[train_index], X_t[test_index]
        y_train, y_test = y[train_index], y[test_index]

        #clf = RandomForestClassifier(n_estimators=400, n_jobs=-1, min_samples_split=2, min_samples_leaf=2, max_features='sqrt', max_depth = 40)
        clf = RandomForestClassifier()
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        
        print('Accuracy on test set: ')
        print(accuracy_score(y_test, y_pred))
        print(confusion_matrix(y_test,y_pred))
        print(classification_report(y_test,y_pred))
        
        acc_score.append(accuracy_score(y_test, y_pred))
    model.append(acc_score)
    print("Average score:", np.mean(acc_score))
    #model.append(acc_score)             

print("Model:", model)
plt.boxplot(model)
plt.title('RF - Boxplot - Embedded feature selection',fontsize=10)
plt.xlabel('10 - 5Folds',fontsize=10)
plt.ylabel('Average score',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.savefig("RandomForeste - 5Flods-Best-subset2.png",dpi=500)
plt.show()
# Out:
# Accuracy on test set:
# 0.9344978165938864
# [[ 37   0   0   0   0]
#  [  0  13   0   2   0]
#  [  0   0 104   3   0]
#  [  0   0   7  33   0]
#  [  2   0   1   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      1.00      0.97        37
#         Her2       1.00      0.87      0.93        15
#         LumA       0.93      0.97      0.95       107
#         LumB       0.87      0.82      0.85        40
#       Normal       1.00      0.90      0.95        30
#
#     accuracy                           0.93       229
#    macro avg       0.95      0.91      0.93       229
# weighted avg       0.94      0.93      0.93       229
#
# Accuracy on test set:
# 0.8864628820960698
# [[35  0  0  0  1]
#  [ 0 15  1  0  0]
#  [ 0  0 99  6  1]
#  [ 0  1 10 30  0]
#  [ 0  0  6  0 24]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        36
#         Her2       0.94      0.94      0.94        16
#         LumA       0.85      0.93      0.89       106
#         LumB       0.83      0.73      0.78        41
#       Normal       0.92      0.80      0.86        30
#
#     accuracy                           0.89       229
#    macro avg       0.91      0.88      0.89       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.8908296943231441
# [[ 34   1   0   1   0]
#  [  1  10   1   4   0]
#  [  0   1 103   2   0]
#  [  0   1   9  31   0]
#  [  0   1   3   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.94      0.96        36
#         Her2       0.71      0.62      0.67        16
#         LumA       0.89      0.97      0.93       106
#         LumB       0.82      0.76      0.78        41
#       Normal       1.00      0.87      0.93        30
#
#     accuracy                           0.89       229
#    macro avg       0.88      0.83      0.85       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.9039301310043668
# [[ 36   0   0   0   0]
#  [  0  10   1   5   0]
#  [  0   0 106   1   0]
#  [  0   1  10  30   0]
#  [  1   2   1   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        36
#         Her2       0.77      0.62      0.69        16
#         LumA       0.90      0.99      0.94       107
#         LumB       0.83      0.73      0.78        41
#       Normal       1.00      0.86      0.93        29
#
#     accuracy                           0.90       229
#    macro avg       0.89      0.84      0.86       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.9078947368421053
# [[ 35   1   0   0   1]
#  [  0  12   1   2   0]
#  [  0   1 101   4   1]
#  [  0   0   7  33   0]
#  [  0   1   2   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.95      0.97        37
#         Her2       0.80      0.80      0.80        15
#         LumA       0.91      0.94      0.93       107
#         LumB       0.85      0.82      0.84        40
#       Normal       0.93      0.90      0.91        29
#
#     accuracy                           0.91       228
#    macro avg       0.90      0.88      0.89       228
# weighted avg       0.91      0.91      0.91       228
#
# Average score: 0.9047230521719145
# Accuracy on test set:
# 0.9213973799126638
# [[ 36   0   0   0   1]
#  [  0  12   0   3   0]
#  [  0   1 103   3   0]
#  [  0   0   7  33   0]
#  [  0   1   2   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.86      0.80      0.83        15
#         LumA       0.92      0.96      0.94       107
#         LumB       0.85      0.82      0.84        40
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.92       229
#    macro avg       0.92      0.89      0.90       229
# weighted avg       0.92      0.92      0.92       229
#
# Accuracy on test set:
# 0.9082969432314411
# [[ 35   0   0   0   1]
#  [  2  13   1   0   0]
#  [  0   0 103   3   0]
#  [  0   0   8  33   0]
#  [  2   1   2   1  24]]
#               precision    recall  f1-score   support
#
#        Basal       0.90      0.97      0.93        36
#         Her2       0.93      0.81      0.87        16
#         LumA       0.90      0.97      0.94       106
#         LumB       0.89      0.80      0.85        41
#       Normal       0.96      0.80      0.87        30
#
#     accuracy                           0.91       229
#    macro avg       0.92      0.87      0.89       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.8908296943231441
# [[ 35   1   0   0   0]
#  [  0  11   2   3   0]
#  [  0   0 101   4   1]
#  [  0   1   9  31   0]
#  [  0   1   3   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        36
#         Her2       0.79      0.69      0.73        16
#         LumA       0.88      0.95      0.91       106
#         LumB       0.82      0.76      0.78        41
#       Normal       0.96      0.87      0.91        30
#
#     accuracy                           0.89       229
#    macro avg       0.89      0.85      0.87       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.8908296943231441
# [[35  0  0  1  0]
#  [ 0 14  0  2  0]
#  [ 0  1 99  5  2]
#  [ 0  0 11 30  0]
#  [ 1  0  2  0 26]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        36
#         Her2       0.93      0.88      0.90        16
#         LumA       0.88      0.93      0.90       107
#         LumB       0.79      0.73      0.76        41
#       Normal       0.93      0.90      0.91        29
#
#     accuracy                           0.89       229
#    macro avg       0.90      0.88      0.89       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.9254385964912281
# [[ 36   1   0   0   0]
#  [  0  11   1   3   0]
#  [  0   0 104   3   0]
#  [  0   1   4  35   0]
#  [  0   0   4   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.85      0.73      0.79        15
#         LumA       0.92      0.97      0.95       107
#         LumB       0.85      0.88      0.86        40
#       Normal       1.00      0.86      0.93        29
#
#     accuracy                           0.93       228
#    macro avg       0.92      0.88      0.90       228
# weighted avg       0.93      0.93      0.92       228
#
# Average score: 0.9073584616563242
# Accuracy on test set:
# 0.9082969432314411
# [[ 37   0   0   0   0]
#  [  0  12   1   2   0]
#  [  0   0 103   4   0]
#  [  0   0   8  32   0]
#  [  1   1   4   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        37
#         Her2       0.92      0.80      0.86        15
#         LumA       0.89      0.96      0.92       107
#         LumB       0.84      0.80      0.82        40
#       Normal       1.00      0.80      0.89        30
#
#     accuracy                           0.91       229
#    macro avg       0.93      0.87      0.90       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.9170305676855895
# [[ 34   1   0   1   0]
#  [  0  13   0   3   0]
#  [  0   0 104   1   1]
#  [  0   0  11  30   0]
#  [  0   0   1   0  29]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.93      0.81      0.87        16
#         LumA       0.90      0.98      0.94       106
#         LumB       0.86      0.73      0.79        41
#       Normal       0.97      0.97      0.97        30
#
#     accuracy                           0.92       229
#    macro avg       0.93      0.89      0.91       229
# weighted avg       0.92      0.92      0.91       229
#
# Accuracy on test set:
# 0.8951965065502183
# [[ 35   0   0   0   1]
#  [  2  11   0   3   0]
#  [  0   0 101   5   0]
#  [  0   0  10  31   0]
#  [  0   0   3   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      0.97      0.96        36
#         Her2       1.00      0.69      0.81        16
#         LumA       0.89      0.95      0.92       106
#         LumB       0.79      0.76      0.77        41
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.90       229
#    macro avg       0.92      0.85      0.88       229
# weighted avg       0.90      0.90      0.89       229
#
# Accuracy on test set:
# 0.8995633187772926
# [[ 36   0   0   0   0]
#  [  0  14   0   2   0]
#  [  0   0 101   6   0]
#  [  0   3   7  31   0]
#  [  1   0   4   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        36
#         Her2       0.82      0.88      0.85        16
#         LumA       0.90      0.94      0.92       107
#         LumB       0.79      0.76      0.77        41
#       Normal       1.00      0.83      0.91        29
#
#     accuracy                           0.90       229
#    macro avg       0.90      0.88      0.89       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.9122807017543859
# [[ 36   1   0   0   0]
#  [  0  11   3   1   0]
#  [  0   1 100   5   1]
#  [  0   0   3  37   0]
#  [  0   2   3   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.73      0.73      0.73        15
#         LumA       0.92      0.93      0.93       107
#         LumB       0.86      0.93      0.89        40
#       Normal       0.96      0.83      0.89        29
#
#     accuracy                           0.91       228
#    macro avg       0.89      0.88      0.89       228
# weighted avg       0.91      0.91      0.91       228
#
# Average score: 0.9064736075997855
# Accuracy on test set:
# 0.9039301310043668
# [[ 35   1   0   0   1]
#  [  1  12   1   1   0]
#  [  0   1 100   6   0]
#  [  0   1   6  33   0]
#  [  0   0   3   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.95      0.96        37
#         Her2       0.80      0.80      0.80        15
#         LumA       0.91      0.93      0.92       107
#         LumB       0.82      0.82      0.82        40
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.90       229
#    macro avg       0.89      0.88      0.89       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.8951965065502183
# [[ 36   0   0   0   0]
#  [  1  10   2   3   0]
#  [  0   0 101   4   1]
#  [  0   1   9  31   0]
#  [  1   1   1   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      1.00      0.97        36
#         Her2       0.83      0.62      0.71        16
#         LumA       0.89      0.95      0.92       106
#         LumB       0.82      0.76      0.78        41
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.90       229
#    macro avg       0.89      0.85      0.87       229
# weighted avg       0.89      0.90      0.89       229
#
# Accuracy on test set:
# 0.9082969432314411
# [[ 36   0   0   0   0]
#  [  0  14   0   2   0]
#  [  0   1 101   2   2]
#  [  0   1   9  31   0]
#  [  0   1   3   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        36
#         Her2       0.82      0.88      0.85        16
#         LumA       0.89      0.95      0.92       106
#         LumB       0.89      0.76      0.82        41
#       Normal       0.93      0.87      0.90        30
#
#     accuracy                           0.91       229
#    macro avg       0.91      0.89      0.90       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.9039301310043668
# [[ 35   0   0   0   1]
#  [  0  13   0   3   0]
#  [  0   0 101   5   1]
#  [  0   0   9  32   0]
#  [  0   0   3   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        36
#         Her2       1.00      0.81      0.90        16
#         LumA       0.89      0.94      0.92       107
#         LumB       0.80      0.78      0.79        41
#       Normal       0.93      0.90      0.91        29
#
#     accuracy                           0.90       229
#    macro avg       0.92      0.88      0.90       229
# weighted avg       0.91      0.90      0.90       229
#
# Accuracy on test set:
# 0.8903508771929824
# [[ 35   1   0   1   0]
#  [  0  11   0   4   0]
#  [  0   0 102   5   0]
#  [  0   0   9  31   0]
#  [  1   1   3   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.95      0.96        37
#         Her2       0.85      0.73      0.79        15
#         LumA       0.89      0.95      0.92       107
#         LumB       0.76      0.78      0.77        40
#       Normal       1.00      0.83      0.91        29
#
#     accuracy                           0.89       228
#    macro avg       0.89      0.85      0.87       228
# weighted avg       0.89      0.89      0.89       228
#
# Average score: 0.9003409177966752
# Accuracy on test set:
# 0.9126637554585153
# [[ 36   0   0   0   1]
#  [  0  11   0   4   0]
#  [  0   1 105   1   0]
#  [  0   0   8  32   0]
#  [  0   0   5   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.92      0.73      0.81        15
#         LumA       0.89      0.98      0.93       107
#         LumB       0.86      0.80      0.83        40
#       Normal       0.96      0.83      0.89        30
#
#     accuracy                           0.91       229
#    macro avg       0.93      0.86      0.89       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.8820960698689956
# [[ 33   2   1   0   0]
#  [  1  12   1   2   0]
#  [  0   0 101   4   1]
#  [  0   0  10  31   0]
#  [  1   1   3   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.94      0.92      0.93        36
#         Her2       0.80      0.75      0.77        16
#         LumA       0.87      0.95      0.91       106
#         LumB       0.84      0.76      0.79        41
#       Normal       0.96      0.83      0.89        30
#
#     accuracy                           0.88       229
#    macro avg       0.88      0.84      0.86       229
# weighted avg       0.88      0.88      0.88       229
#
# Accuracy on test set:
# 0.9126637554585153
# [[36  0  0  0  0]
#  [ 0 12  0  4  0]
#  [ 0  0 99  5  2]
#  [ 0  0  6 35  0]
#  [ 0  2  1  0 27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        36
#         Her2       0.86      0.75      0.80        16
#         LumA       0.93      0.93      0.93       106
#         LumB       0.80      0.85      0.82        41
#       Normal       0.93      0.90      0.92        30
#
#     accuracy                           0.91       229
#    macro avg       0.90      0.89      0.89       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.9082969432314411
# [[ 35   0   0   0   1]
#  [  0  14   1   1   0]
#  [  0   0 102   5   0]
#  [  0   1   9  31   0]
#  [  0   1   1   1  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        36
#         Her2       0.88      0.88      0.88        16
#         LumA       0.90      0.95      0.93       107
#         LumB       0.82      0.76      0.78        41
#       Normal       0.96      0.90      0.93        29
#
#     accuracy                           0.91       229
#    macro avg       0.91      0.89      0.90       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.9429824561403509
# [[ 37   0   0   0   0]
#  [  1  12   1   1   0]
#  [  0   0 103   3   1]
#  [  0   1   4  35   0]
#  [  0   0   1   0  28]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        37
#         Her2       0.92      0.80      0.86        15
#         LumA       0.94      0.96      0.95       107
#         LumB       0.90      0.88      0.89        40
#       Normal       0.97      0.97      0.97        29
#
#     accuracy                           0.94       228
#    macro avg       0.94      0.92      0.93       228
# weighted avg       0.94      0.94      0.94       228
#
# Average score: 0.9117405960315634
# Accuracy on test set:
# 0.9213973799126638
# [[ 36   0   1   0   0]
#  [  0  14   0   1   0]
#  [  0   1 101   4   1]
#  [  0   0   7  33   0]
#  [  0   0   2   1  27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.93      0.93      0.93        15
#         LumA       0.91      0.94      0.93       107
#         LumB       0.85      0.82      0.84        40
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.92       229
#    macro avg       0.93      0.92      0.92       229
# weighted avg       0.92      0.92      0.92       229
#
# Accuracy on test set:
# 0.9039301310043668
# [[ 34   0   0   0   2]
#  [  0  13   1   2   0]
#  [  0   0 103   3   0]
#  [  0   1   8  32   0]
#  [  1   1   3   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.94      0.96        36
#         Her2       0.87      0.81      0.84        16
#         LumA       0.90      0.97      0.93       106
#         LumB       0.86      0.78      0.82        41
#       Normal       0.93      0.83      0.88        30
#
#     accuracy                           0.90       229
#    macro avg       0.90      0.87      0.89       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.925764192139738
# [[ 35   1   0   0   0]
#  [  0  12   1   3   0]
#  [  0   0 103   2   1]
#  [  0   0   7  34   0]
#  [  1   0   1   0  28]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        36
#         Her2       0.92      0.75      0.83        16
#         LumA       0.92      0.97      0.94       106
#         LumB       0.87      0.83      0.85        41
#       Normal       0.97      0.93      0.95        30
#
#     accuracy                           0.93       229
#    macro avg       0.93      0.89      0.91       229
# weighted avg       0.93      0.93      0.92       229
#
# Accuracy on test set:
# 0.8864628820960698
# [[ 36   0   0   0   0]
#  [  2  11   0   3   0]
#  [  0   1 104   2   0]
#  [  0   0  12  29   0]
#  [  1   1   4   0  23]]
#               precision    recall  f1-score   support
#
#        Basal       0.92      1.00      0.96        36
#         Her2       0.85      0.69      0.76        16
#         LumA       0.87      0.97      0.92       107
#         LumB       0.85      0.71      0.77        41
#       Normal       1.00      0.79      0.88        29
#
#     accuracy                           0.89       229
#    macro avg       0.90      0.83      0.86       229
# weighted avg       0.89      0.89      0.88       229
#
# Accuracy on test set:
# 0.8903508771929824
# [[ 36   1   0   0   0]
#  [  0  13   0   2   0]
#  [  0   0 101   4   2]
#  [  0   2  10  28   0]
#  [  0   1   3   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        37
#         Her2       0.76      0.87      0.81        15
#         LumA       0.89      0.94      0.91       107
#         LumB       0.82      0.70      0.76        40
#       Normal       0.93      0.86      0.89        29
#
#     accuracy                           0.89       228
#    macro avg       0.88      0.87      0.87       228
# weighted avg       0.89      0.89      0.89       228
#
# Average score: 0.9055810924691642
# Accuracy on test set:
# 0.9039301310043668
# [[ 36   0   0   0   1]
#  [  0  12   1   2   0]
#  [  0   0 101   6   0]
#  [  0   0   7  33   0]
#  [  1   1   3   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        37
#         Her2       0.92      0.80      0.86        15
#         LumA       0.90      0.94      0.92       107
#         LumB       0.80      0.82      0.81        40
#       Normal       0.96      0.83      0.89        30
#
#     accuracy                           0.90       229
#    macro avg       0.91      0.88      0.89       229
# weighted avg       0.91      0.90      0.90       229
#
# Accuracy on test set:
# 0.8864628820960698
# [[36  0  0  0  0]
#  [ 0 12  0  4  0]
#  [ 0  0 99  5  2]
#  [ 0  1 10 30  0]
#  [ 0  2  2  0 26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        36
#         Her2       0.80      0.75      0.77        16
#         LumA       0.89      0.93      0.91       106
#         LumB       0.77      0.73      0.75        41
#       Normal       0.93      0.87      0.90        30
#
#     accuracy                           0.89       229
#    macro avg       0.88      0.86      0.87       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.925764192139738
# [[ 35   1   0   0   0]
#  [  1  13   1   1   0]
#  [  0   0 104   2   0]
#  [  0   1   6  34   0]
#  [  1   0   3   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      0.97      0.96        36
#         Her2       0.87      0.81      0.84        16
#         LumA       0.91      0.98      0.95       106
#         LumB       0.92      0.83      0.87        41
#       Normal       1.00      0.87      0.93        30
#
#     accuracy                           0.93       229
#    macro avg       0.93      0.89      0.91       229
# weighted avg       0.93      0.93      0.92       229
#
# Accuracy on test set:
# 0.8995633187772926
# [[34  2  0  0  0]
#  [ 0 12  2  2  0]
#  [ 0  2 99  6  0]
#  [ 0  1  7 33  0]
#  [ 0  0  1  0 28]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.71      0.75      0.73        16
#         LumA       0.91      0.93      0.92       107
#         LumB       0.80      0.80      0.80        41
#       Normal       1.00      0.97      0.98        29
#
#     accuracy                           0.90       229
#    macro avg       0.88      0.88      0.88       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.9254385964912281
# [[ 37   0   0   0   0]
#  [  0  13   0   2   0]
#  [  0   0 104   3   0]
#  [  0   0   7  33   0]
#  [  0   0   5   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        37
#         Her2       1.00      0.87      0.93        15
#         LumA       0.90      0.97      0.93       107
#         LumB       0.87      0.82      0.85        40
#       Normal       1.00      0.83      0.91        29
#
#     accuracy                           0.93       228
#    macro avg       0.95      0.90      0.92       228
# weighted avg       0.93      0.93      0.92       228
#
# Average score: 0.908231824101739
# Accuracy on test set:
# 0.8864628820960698
# [[ 37   0   0   0   0]
#  [  1  11   1   2   0]
#  [  0   0 102   5   0]
#  [  0   1   8  31   0]
#  [  1   1   6   0  22]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      1.00      0.97        37
#         Her2       0.85      0.73      0.79        15
#         LumA       0.87      0.95      0.91       107
#         LumB       0.82      0.78      0.79        40
#       Normal       1.00      0.73      0.85        30
#
#     accuracy                           0.89       229
#    macro avg       0.90      0.84      0.86       229
# weighted avg       0.89      0.89      0.88       229
#
# Accuracy on test set:
# 0.9170305676855895
# [[ 35   0   0   0   1]
#  [  0  13   1   2   0]
#  [  0   0 102   3   1]
#  [  0   0   8  33   0]
#  [  1   0   2   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        36
#         Her2       1.00      0.81      0.90        16
#         LumA       0.90      0.96      0.93       106
#         LumB       0.87      0.80      0.84        41
#       Normal       0.93      0.90      0.92        30
#
#     accuracy                           0.92       229
#    macro avg       0.93      0.89      0.91       229
# weighted avg       0.92      0.92      0.92       229
#
# Accuracy on test set:
# 0.9082969432314411
# [[ 34   1   0   1   0]
#  [  0  11   0   5   0]
#  [  0   0 101   5   0]
#  [  0   0   6  35   0]
#  [  0   0   3   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.92      0.69      0.79        16
#         LumA       0.92      0.95      0.94       106
#         LumB       0.76      0.85      0.80        41
#       Normal       1.00      0.90      0.95        30
#
#     accuracy                           0.91       229
#    macro avg       0.92      0.87      0.89       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.925764192139738
# [[ 35   0   0   0   1]
#  [  0  13   1   2   0]
#  [  0   0 103   3   1]
#  [  0   1   6  34   0]
#  [  1   0   1   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        36
#         Her2       0.93      0.81      0.87        16
#         LumA       0.93      0.96      0.94       107
#         LumB       0.87      0.83      0.85        41
#       Normal       0.93      0.93      0.93        29
#
#     accuracy                           0.93       229
#    macro avg       0.93      0.90      0.91       229
# weighted avg       0.93      0.93      0.93       229
#
# Accuracy on test set:
# 0.8771929824561403
# [[ 36   1   0   0   0]
#  [  1  14   0   0   0]
#  [  0   1 100   6   0]
#  [  0   0  14  26   0]
#  [  0   2   3   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      0.97      0.97        37
#         Her2       0.78      0.93      0.85        15
#         LumA       0.85      0.93      0.89       107
#         LumB       0.81      0.65      0.72        40
#       Normal       1.00      0.83      0.91        29
#
#     accuracy                           0.88       228
#    macro avg       0.88      0.86      0.87       228
# weighted avg       0.88      0.88      0.87       228
#
# Average score: 0.9029495135217956
# Accuracy on test set:
# 0.9170305676855895
# [[ 37   0   0   0   0]
#  [  2  12   1   0   0]
#  [  0   0 104   3   0]
#  [  0   0   9  31   0]
#  [  0   2   2   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      1.00      0.97        37
#         Her2       0.86      0.80      0.83        15
#         LumA       0.90      0.97      0.93       107
#         LumB       0.91      0.78      0.84        40
#       Normal       1.00      0.87      0.93        30
#
#     accuracy                           0.92       229
#    macro avg       0.92      0.88      0.90       229
# weighted avg       0.92      0.92      0.92       229
#
# Accuracy on test set:
# 0.8995633187772926
# [[ 35   1   0   0   0]
#  [  0  14   1   1   0]
#  [  0   0 102   4   0]
#  [  0   1  10  30   0]
#  [  0   0   5   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.97      0.99        36
#         Her2       0.88      0.88      0.88        16
#         LumA       0.86      0.96      0.91       106
#         LumB       0.86      0.73      0.79        41
#       Normal       1.00      0.83      0.91        30
#
#     accuracy                           0.90       229
#    macro avg       0.92      0.87      0.89       229
# weighted avg       0.90      0.90      0.90       229
#
# Accuracy on test set:
# 0.8908296943231441
# [[34  1  0  0  1]
#  [ 0 14  0  2  0]
#  [ 0  1 99  4  2]
#  [ 0  0 11 30  0]
#  [ 0  0  3  0 27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.88      0.88      0.88        16
#         LumA       0.88      0.93      0.90       106
#         LumB       0.83      0.73      0.78        41
#       Normal       0.90      0.90      0.90        30
#
#     accuracy                           0.89       229
#    macro avg       0.90      0.88      0.89       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.8908296943231441
# [[ 36   0   0   0   0]
#  [  0   8   2   6   0]
#  [  0   0 101   6   0]
#  [  0   1   7  33   0]
#  [  0   1   2   0  26]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00        36
#         Her2       0.80      0.50      0.62        16
#         LumA       0.90      0.94      0.92       107
#         LumB       0.73      0.80      0.77        41
#       Normal       1.00      0.90      0.95        29
#
#     accuracy                           0.89       229
#    macro avg       0.89      0.83      0.85       229
# weighted avg       0.89      0.89      0.89       229
#
# Accuracy on test set:
# 0.9122807017543859
# [[ 35   0   0   1   1]
#  [  0  12   0   3   0]
#  [  0   0 105   2   0]
#  [  0   0   9  31   0]
#  [  2   0   2   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      0.95      0.95        37
#         Her2       1.00      0.80      0.89        15
#         LumA       0.91      0.98      0.94       107
#         LumB       0.84      0.78      0.81        40
#       Normal       0.96      0.86      0.91        29
#
#     accuracy                           0.91       228
#    macro avg       0.93      0.87      0.90       228
# weighted avg       0.91      0.91      0.91       228
#
# Average score: 0.9021067953727112
# Accuracy on test set:
# 0.9082969432314411
# [[ 37   0   0   0   0]
#  [  0  11   0   4   0]
#  [  0   0 101   5   1]
#  [  0   1   5  34   0]
#  [  1   1   3   0  25]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        37
#         Her2       0.85      0.73      0.79        15
#         LumA       0.93      0.94      0.94       107
#         LumB       0.79      0.85      0.82        40
#       Normal       0.96      0.83      0.89        30
#
#     accuracy                           0.91       229
#    macro avg       0.90      0.87      0.88       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.8951965065502183
# [[ 34   0   0   1   1]
#  [  0  13   1   2   0]
#  [  0   1 101   3   1]
#  [  0   1  10  30   0]
#  [  0   1   2   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.81      0.81      0.81        16
#         LumA       0.89      0.95      0.92       106
#         LumB       0.83      0.73      0.78        41
#       Normal       0.93      0.90      0.92        30
#
#     accuracy                           0.90       229
#    macro avg       0.89      0.87      0.88       229
# weighted avg       0.90      0.90      0.89       229
#
# Accuracy on test set:
# 0.9082969432314411
# [[ 35   1   0   0   0]
#  [  1  12   1   2   0]
#  [  0   1 101   3   1]
#  [  0   0   8  33   0]
#  [  1   0   2   0  27]]
#               precision    recall  f1-score   support
#
#        Basal       0.95      0.97      0.96        36
#         Her2       0.86      0.75      0.80        16
#         LumA       0.90      0.95      0.93       106
#         LumB       0.87      0.80      0.84        41
#       Normal       0.96      0.90      0.93        30
#
#     accuracy                           0.91       229
#    macro avg       0.91      0.88      0.89       229
# weighted avg       0.91      0.91      0.91       229
#
# Accuracy on test set:
# 0.9039301310043668
# [[ 34   1   0   0   1]
#  [  0  13   1   2   0]
#  [  0   1 103   3   0]
#  [  0   1   7  33   0]
#  [  0   1   4   0  24]]
#               precision    recall  f1-score   support
#
#        Basal       1.00      0.94      0.97        36
#         Her2       0.76      0.81      0.79        16
#         LumA       0.90      0.96      0.93       107
#         LumB       0.87      0.80      0.84        41
#       Normal       0.96      0.83      0.89        29
#
#     accuracy                           0.90       229
#    macro avg       0.90      0.87      0.88       229
# weighted avg       0.91      0.90      0.90       229
#
# Accuracy on test set:
# 0.9166666666666666
# [[ 37   0   0   0   0]
#  [  1  10   1   3   0]
#  [  0   1 102   3   1]
#  [  0   0   8  32   0]
#  [  0   0   1   0  28]]
#               precision    recall  f1-score   support
#
#        Basal       0.97      1.00      0.99        37
#         Her2       0.91      0.67      0.77        15
#         LumA       0.91      0.95      0.93       107
#         LumB       0.84      0.80      0.82        40
#       Normal       0.97      0.97      0.97        29
#
#     accuracy                           0.92       228
#    macro avg       0.92      0.88      0.89       228
# weighted avg       0.92      0.92      0.91       228
#
# Average score: 0.9064774381368268
# Model: [[0.9344978165938864, 0.8864628820960698, 0.8908296943231441, 0.9039301310043668, 0.9078947368421053], [0.9213973799126638, 0.9082969432314411, 0.8908296943231441, 0.8908296943231441, 0.9254385964912281], [0.9082969432314411, 0.9170305676855895, 0.8951965065502183, 0.8995633187772926, 0.9122807017543859], [0.9039301310043668, 0.8951965065502183, 0.9082969432314411, 0.9039301310043668, 0.8903508771929824], [0.9126637554585153, 0.8820960698689956, 0.9126637554585153, 0.9082969432314411, 0.9429824561403509], [0.9213973799126638, 0.9039301310043668, 0.925764192139738, 0.8864628820960698, 0.8903508771929824], [0.9039301310043668, 0.8864628820960698, 0.925764192139738, 0.8995633187772926, 0.9254385964912281], [0.8864628820960698, 0.9170305676855895, 0.9082969432314411, 0.925764192139738, 0.8771929824561403], [0.9170305676855895, 0.8995633187772926, 0.8908296943231441, 0.8908296943231441, 0.9122807017543859], [0.9082969432314411, 0.8951965065502183, 0.9082969432314411, 0.9039301310043668, 0.9166666666666666]]

# %%
import numpy as np
np.mean([[0.9039301310043668, 0.8951965065502183, 0.9039301310043668, 0.9082969432314411, 0.9122807017543859], [0.9344978165938864, 0.8908296943231441, 0.9170305676855895, 0.8951965065502183, 0.9078947368421053], [0.9170305676855895, 0.9170305676855895, 0.9039301310043668, 0.9039301310043668, 0.881578947368421], [0.9039301310043668, 0.8995633187772926, 0.9126637554585153, 0.9301310043668122, 0.9122807017543859], [0.9039301310043668, 0.925764192139738, 0.9082969432314411, 0.9039301310043668, 0.881578947368421], [0.9388646288209607, 0.8733624454148472, 0.9126637554585153, 0.8908296943231441, 0.9035087719298246], [0.8908296943231441, 0.8951965065502183, 0.9126637554585153, 0.8908296943231441, 0.9429824561403509], [0.9082969432314411, 0.9082969432314411, 0.8995633187772926, 0.9126637554585153, 0.9078947368421053], [0.9082969432314411, 0.9039301310043668, 0.9213973799126638, 0.9126637554585153, 0.9122807017543859], [0.8951965065502183, 0.9213973799126638, 0.9039301310043668, 0.9082969432314411, 0.9166666666666666]])
# Out:
# 0.907343139508159

# %%
np.mean([[0.9126637554585153, 0.8908296943231441, 0.8777292576419214, 0.925764192139738, 0.8947368421052632], [0.8908296943231441, 0.9082969432314411, 0.8908296943231441, 0.8864628820960698, 0.9122807017543859], [0.8864628820960698, 0.9039301310043668, 0.9039301310043668, 0.9126637554585153, 0.8859649122807017], [0.8777292576419214, 0.8733624454148472, 0.9475982532751092, 0.8995633187772926, 0.881578947368421], [0.8864628820960698, 0.8995633187772926, 0.9039301310043668, 0.9213973799126638, 0.9078947368421053], [0.8951965065502183, 0.8995633187772926, 0.8820960698689956, 0.9388646288209607, 0.8991228070175439], [0.8995633187772926, 0.9082969432314411, 0.9388646288209607, 0.8733624454148472, 0.881578947368421], [0.9039301310043668, 0.8908296943231441, 0.9082969432314411, 0.9082969432314411, 0.881578947368421], [0.9301310043668122, 0.9126637554585153, 0.8908296943231441, 0.8733624454148472, 0.9035087719298246], [0.8864628820960698, 0.9126637554585153, 0.8995633187772926, 0.8951965065502183, 0.9166666666666666]])
# Out:
# 0.9002589443039913

# %%
df[features[5]].columns
# Out:
# Index(['AGR3', 'GABRP', 'FABP7', 'AGR2', 'VGLL1', 'ESR1', 'FOXA1', 'NAT1',
#        'FLJ45983', 'PPP1R14C', 'LOC145837', 'CA12', 'MLPH', 'CNTNAP3', 'SYNM',
#        'GATA3', 'ID4', 'FZD9', 'THSD4', 'UBE2C', 'FOXC1', 'KIF14', 'SIDT1',
#        'NUF2', 'DLGAP5', 'FOXM1', 'SGOL1', 'HJURP', 'INPP4B', 'CEP55', 'TTK',
#        'NFIB', 'BUB1B', 'MAML2', 'CMBL', 'SLC7A13', 'FAM171A1', 'AURKA',
#        'C6orf211', 'FAM72B', 'CDKN3', 'C9orf116', 'KIF18A', 'CENPW', 'GINS1',
#        'EZH2', 'MAD2L1', 'MTHFD1L', 'KPNA2', 'TLE3'],
#       dtype='object')

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

model = list()


for x in range(1,11):

    acc_score = []

    X_t=df[features[1]].to_numpy()

    clf = make_pipeline(StandardScaler(), SVC(kernel="linear", C = 0.1,decision_function_shape='ovo', class_weight = None))
    cv = ShuffleSplit(n_splits=5, test_size=0.3)
    model.append(cross_val_score(clf, X_t, y, cv=cv).tolist())
    #print("Average score:", np.mean(acc_score))
    #model.append(acc_score)             

print("Model:", model)
print("Model average :", np.mean(model))
plt.boxplot(model)
plt.title('RF Final evaluation',fontsize=10)
plt.xlabel('10 - 5Folds',fontsize=10)
plt.ylabel('Average score',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.savefig("RFFinalevaluation.png",dpi=500)
plt.show()
# Out:
# Model: [[0.9011627906976745, 0.9040697674418605, 0.8837209302325582, 0.8982558139534884, 0.9040697674418605], [0.9156976744186046, 0.9098837209302325, 0.9069767441860465, 0.8924418604651163, 0.8924418604651163], [0.8866279069767442, 0.9302325581395349, 0.8924418604651163, 0.8953488372093024, 0.8808139534883721], [0.9244186046511628, 0.8953488372093024, 0.9156976744186046, 0.8924418604651163, 0.8982558139534884], [0.9156976744186046, 0.8982558139534884, 0.9011627906976745, 0.9215116279069767, 0.9186046511627907], [0.8982558139534884, 0.8866279069767442, 0.9069767441860465, 0.8953488372093024, 0.8837209302325582], [0.8837209302325582, 0.9098837209302325, 0.9273255813953488, 0.8895348837209303, 0.8924418604651163], [0.8866279069767442, 0.8895348837209303, 0.8808139534883721, 0.9098837209302325, 0.9156976744186046], [0.9040697674418605, 0.9069767441860465, 0.8895348837209303, 0.9273255813953488, 0.8924418604651163], [0.8895348837209303, 0.9098837209302325, 0.8953488372093024, 0.9156976744186046, 0.9011627906976745]]
# Model average : 0.9012790697674419
